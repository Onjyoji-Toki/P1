# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
hist1 = np.load('/Users/r.shinoda/p1/data/down01241002/01241002downwith27loops.npy')

# %%
hist2 = np.load('/Users/r.shinoda/p1/data/down01241541/01241541downwith25loops.npy')

# %%
hist = hist1 + hist2

# %%
edges = np.load('/Users/r.shinoda/p1/data/caribration/down/down_keV_edges.npy')

# %%
plt.plot(edges, hist)
plt.yscale('log')
#plt.xlim([900, 1000])
plt.xlabel('Energy [keV]')
plt.ylabel('counts')
plt.grid(True)

# %%
hist3 = np.load('/Users/r.shinoda/p1/data/up01241002/01241002upwith27loops.npy')

# %%
hist4 = np.load('/Users/r.shinoda/p1/data/up01241541/01241541upwith24loops.npy')

# %%
hist5 = hist3 + hist4

# %%
plt.plot(edges, hist5)
plt.yscale('log')
#plt.xlim([900, 1000])
plt.xlabel('Energy [keV]')
plt.ylabel('counts')
plt.grid(True)

# %%
diff = hist - hist5
plt.plot(edges, diff)
#plt.yscale('log')
#plt.xlim([900, 1000])
plt.xlabel('Energy [keV]')
plt.ylabel('counts')
plt.grid(True)
