# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
s = np.load('/Users/r.shinoda/Desktop/0610Eu152edges.npy')
t = np.load('/Users/r.shinoda/Desktop/0610Eu152hist.npy')

# %%
u = np.load('/Users/r.shinoda/p1/data/down02131758/02131758down_edges.npy')
v = np.load('/Users/r.shinoda/p1/data/down02131758/02131758downwith75loops.npy')

# %%
w = np.load('/Users/r.shinoda/p1/data/up02131758/02131758up_edges.npy')
x = np.load('/Users/r.shinoda/p1/data/up02131758/02131758upwith75loops.npy')

# %%
y = np.load('/Users/r.shinoda/Desktop/1602Eu152edges.npy')
z = np.load('/Users/r.shinoda/Desktop/1602Eu152hist.npy')

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(2,2,1)
ax1.scatter(s[:-1],t,s=0.5)
ax1.set_yscale('log')
ax2 = fig.add_subplot(2,2,2)
ax2.scatter(u[:-1],v,s=0.5)
ax2.set_yscale('log')
ax3 = fig.add_subplot(2,2,3)
ax3.scatter(w[:-1],x,s=0.5)
ax3.set_yscale('log')

# %%
plt.scatter(s[:-1],t,s=0.5,label='0610end')
plt.scatter(u[:-1],v,s=0.5,label='downwith75loops')
plt.scatter(w[:-1],x,s=0.5,label='upwith75loops')
plt.scatter(y[:-1],z,s=0.5,label='1602first')
plt.legend()
plt.yscale('log')

# %%
plt.scatter(s[:-1],t,s=0.5,label='0610end')
plt.scatter(y[:-1],z,s=0.5,label='1602first')
plt.legend()
plt.yscale('log')

# %%
1/(1.4e-1 * 1.7)
# Out:
# 4.201680672268907
